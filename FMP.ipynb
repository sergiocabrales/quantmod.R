# %% [markdown]
# <a href="https://colab.research.google.com/github/sergio-cabrales/quantmod.R/blob/master/FMP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install FundamentalAnalysis
# Out:
# Collecting FundamentalAnalysis
#   Downloading https://files.pythonhosted.org/packages/46/dc/e406176367089af57e0e2ec2043b4e2bf81cc9cd1184f51e4a0de5a1296b/FundamentalAnalysis-0.2.6.tar.gz
# Building wheels for collected packages: FundamentalAnalysis
#   Building wheel for FundamentalAnalysis (setup.py) ... done
#   Created wheel for FundamentalAnalysis: filename=FundamentalAnalysis-0.2.6-cp37-none-any.whl size=9733 sha256=4cb439d5869ebd5156cf4296bebde9c72ee44b229d2fb91f56a7ec061e15f7e3
#   Stored in directory: /root/.cache/pip/wheels/d2/09/b7/cae273de32fdaa5dae02f207e91294b40fd1cba026448116a3
# Successfully built FundamentalAnalysis
# Installing collected packages: FundamentalAnalysis
# Successfully installed FundamentalAnalysis-0.2.6

# %%
import FundamentalAnalysis as fa

# %%
import FundamentalAnalysis as fa

ticker = "AAPL"
api_key = "XXXX"

# Show the available companies
companies = fa.available_companies(api_key)

companies
# Out:
#                                                  name  ...                 exchange
# symbol                                                 ...
# SPY                                      SPDR S&P 500  ...                NYSE Arca
# CMCSA                                    Comcast Corp  ...     Nasdaq Global Select
# KMI                                 Kinder Morgan Inc  ...  New York Stock Exchange
# INTC                                       Intel Corp  ...     Nasdaq Global Select
# MU                              Micron Technology Inc  ...     Nasdaq Global Select
# ...                                               ...  ...                      ...
# EUSG    European Sustainable Growth Acquisition Corp.  ...                   Nasdaq
# MNOW.V                                    Mednow Inc.  ...                     TSXV
# EUSGW   European Sustainable Growth Acquisition Corp.  ...                   Nasdaq
# VAQC                       Vector Acquisition Corp II  ...                   Nasdaq
# RBLX                                      Roblox Corp  ...                     NYSE
#
# [29244 rows x 3 columns]

# %%
# Collect general company information
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                          AAPL
# price                                                         120.42
# beta                                                         1.33758
# volAvg                                                     111377613
# mktCap                                                 2021622940000
# lastDiv                                                         0.82
# range                                                 53.1525-145.09
# changes                                                       -0.665
# companyName                                                Apple Inc
# currency                                                         USD
# cik                                                       0000320193
# isin                                                    US0378331005
# cusip                                                      037833100
# exchange                                        Nasdaq Global Select
# exchangeShortName                                             NASDAQ
# industry                                        Consumer Electronics
# website                                       https://www.apple.com/
# description        Apple Inc. designs, manufactures, and markets ...
# ceo                                                 Mr. Timothy Cook
# sector                                                    Technology
# country                                                           US
# fullTimeEmployees                                             147000
# phone                                                    14089961010
# address                                             1 Apple Park Way
# city                                                       Cupertino
# state                                                     CALIFORNIA
# zip                                                            95014
# dcfDiff                                                        89.92
# dcf                                                          127.377
# image              https://financialmodelingprep.com/image-stock/...
# ipoDate                                                   1980-12-12
# defaultImage                                                   False
# isEtf                                                          False
# isActivelyTrading                                               True

# %%
# Collect recent company quotes
quotes = fa.quote(ticker, api_key)

# Collect market cap and enterprise value
entreprise_value = fa.enterprise(ticker, api_key)

# Show recommendations of Analysts
ratings = fa.rating(ticker, api_key)

# Obtain DCFs over time
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_quarterly = fa.discounted_cash_flow(ticker, api_key, period="quarter")

# Collect the Balance Sheet statements
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")
balance_sheet_quarterly = fa.balance_sheet_statement(ticker, api_key, period="quarter")

# Collect the Income Statements
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
income_statement_quarterly = fa.income_statement(ticker, api_key, period="quarter")

# Collect the Cash Flow Statements
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
cash_flow_statement_quarterly = fa.cash_flow_statement(ticker, api_key, period="quarter")

# Show Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")

# Show a large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")

# Show the growth of the company
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")

# Download general stock data
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")

# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2020-01-01")

# %%
# Show Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_annually
# Out:
#                                                 2020  ...          1985
# revenuePerShare                         1.582026e+01  ...  1.383439e-01
# netIncomePerShare                       3.308587e+00  ...  4.399885e-03
# operatingCashFlowPerShare               4.649230e+00  ...  1.911425e-02
# freeCashFlowPerShare                    4.228014e+00  ...  1.521927e-02
# cashPerShare                            2.190856e+00  ...  2.430756e-02
# bookValuePerShare                       3.765477e+00  ...  3.967109e-02
# tangibleBookValuePerShare               1.866562e+01  ...  6.751298e-02
# shareholdersEquityPerShare              3.765477e+00  ...  3.967109e-02
# interestDebtPerShare                    6.645240e+00  ...  0.000000e+00
# marketCap                               1.996361e+12  ...  1.114069e+09
# enterpriseValue                         2.070781e+12  ...  7.770694e+08
# peRatio                                 3.477315e+01  ...  1.826343e+01
# priceToSalesRatio                       7.272322e+00  ...  5.808496e-01
# pocfratio                               2.474603e+01  ...  4.204036e+00
# pfcfRatio                               2.721136e+01  ...  5.279950e+00
# pbRatio                                 3.055390e+01  ...  2.025581e+00
# ptbRatio                                3.055390e+01  ...  2.025581e+00
# evToSales                               7.543418e+00  ...  4.051457e-01
# enterpriseValueOverEBITDA               2.555889e+01  ...  4.796725e+00
# evToOperatingCashFlow                   2.566851e+01  ...  2.932338e+00
# evToFreeCashFlow                        2.822574e+01  ...  3.682794e+00
# earningsYield                           2.875782e-02  ...  5.475422e-02
# freeCashFlowYield                       3.674936e-02  ...  1.893957e-01
# debtToEquity                            3.957039e+00  ...  7.018182e-01
# debtToAssets                            7.982667e-01  ...  4.123932e-01
# netDebtToEBITDA                         9.185386e-01  ... -2.080247e+00
# currentRatio                            1.363604e+00  ...  2.786441e+00
# interestCoverage                        2.335225e+01  ...           NaN
# incomeQuality                           1.405201e+00  ...  4.344262e+00
# dividendYield                           7.053332e-03  ...           NaN
# payoutRatio                             2.452666e-01  ...  0.000000e+00
# salesGeneralAndAdministrativeToRevenue  0.000000e+00  ...  0.000000e+00
# researchAndDdevelopementToRevenue       6.830956e-02  ...  3.806048e-02
# intangiblesToTotalAssets                0.000000e+00  ...  0.000000e+00
# capexToOperatingCashFlow               -1.103762e+01  ... -4.907407e+00
# capexToRevenue                         -3.755849e+01  ... -3.551852e+01
# capexToDepreciation                    -1.512656e+00  ... -7.777778e-01
# stockBasedCompensationToRevenue         2.487660e-02  ...  0.000000e+00
# grahamNumber                            1.674259e+01  ...  6.266845e-02
# roic                                    3.070583e-01  ...  1.872075e-01
# returnOnTangibleAssets                  1.772557e-01  ...  6.517094e-02
# grahamNetNet                           -7.923629e+00  ...  1.438979e-02
# workingCapital                          3.832100e+10  ...  5.270000e+08
# tangibleAssetValue                               NaN  ...           NaN
# netCurrentAssetValue                   -1.148360e+11  ...  4.360000e+08
# investedCapital                                  NaN  ...           NaN
# averageReceivables                      4.162450e+10  ...  2.301200e+10
# averagePayables                         4.426600e+10  ...  2.315550e+10
# averageInventory                        4.083500e+09  ...  2.136500e+09
# daysSalesOutstanding                    4.978753e+01  ...  4.186653e+01
# daysPayablesOutstanding                 9.104819e+01  ...  2.448569e+01
# daysOfInventoryOnHand                   8.741883e+00  ...  5.452147e+01
# receivablesTurnover                     7.331152e+00  ...  8.718182e+00
# payablesTurnover                        4.008866e+00  ...  1.490667e+01
# inventoryTurnover                       4.175302e+01  ...  6.694611e+00
# roe                                     8.786636e-01  ...  1.109091e-01
# capexPerShare                          -4.212166e-01  ... -3.894980e-03
#
# [57 rows x 36 columns]

# %%
# Show a large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annua")
financial_ratios_annually
# Out:
#                                           2020       2019  ...       1986       1985
# period                                      FY         FY  ...         FY         FY
# currentRatio                            1.3636    1.54013  ...    3.16413    2.78644
# quickRatio                             1.21819    1.38445  ...    2.55015    1.88814
# cashRatio                              0.36071   0.462022  ...    1.75076    1.14237
# daysOfSalesOutstanding                 49.7875    64.2588  ...    50.4706    41.8665
# daysOfInventoryOutstanding             8.74188    9.26364  ...    44.6521    54.5215
# operatingCycle                         58.5294    73.5224  ...    95.1226     96.388
# daysOfPayablesOutstanding              91.0482    104.314  ...    48.3389    24.4857
# cashConversionCycle                   -32.5188   -30.7917  ...    46.7837    71.9023
# grossProfitMargin                     0.382332   0.378178  ...   0.531546   0.417101
# operatingProfitMargin                 0.241473    0.24572  ...   0.144059  0.0537018
# pretaxProfitMargin                    0.244398   0.252666  ...   0.162986  0.0625652
# netProfitMargin                       0.209136   0.212381  ...  0.0809674   0.031804
# effectiveTaxRate                      0.144282   0.159438  ...   0.503226   0.491667
# returnOnAssets                        0.177256    0.16323  ...   0.132759  0.0651709
# returnOnEquity                        0.878664   0.610645  ...   0.221902   0.110909
# returnOnCapitalEmployed               0.307058   0.282378  ...   0.373045   0.187207
# netIncomePerEBT                       0.855718   0.840562  ...   0.496774   0.508333
# ebtPerEbit                                   1          1  ...          1          1
# ebitPerRevenue                        0.244398   0.252666  ...   0.162986  0.0625652
# debtRatio                             0.798267   0.732692  ...   0.401724   0.412393
# debtEquityRatio                        3.95704      2.741  ...    0.67147   0.701818
# longTermDebtToCapitalization          0.601606   0.503618  ...       None       None
# totalDebtToCapitalization             0.632462   0.538477  ...       None       None
# interestCoverage                       23.3522    18.3828  ...       None       None
# cashFlowToDebtRatio                    0.71751   0.657261  ...       None       None
# companyEquityMultiplier                4.95704      3.741  ...    1.67147    1.70182
# receivablesTurnover                    7.33115    5.68016  ...    7.23194    8.71818
# payablesTurnover                       4.00887    3.49905  ...    7.55085    14.9067
# inventoryTurnover                       41.753    39.4014  ...    8.17431    6.69461
# fixedAssetTurnover                     7.46655    6.96062  ...    17.7757    21.3111
# assetTurnover                         0.847562   0.768572  ...    1.63966    2.04915
# operatingCashFlowPerShare              4.64923    3.75669  ...  0.0218629  0.0191143
# freeCashFlowPerShare                   4.22801    3.18851  ...  0.0172127  0.0152193
# cashPerShare                           5.24103    5.44395  ...  0.0399778  0.0243076
# payoutRatio                           0.245267    0.25552  ...          0          0
# operatingCashFlowSalesRatio           0.293878    0.26671  ...   0.165615   0.138165
# freeCashFlowOperatingCashFlowRatio    0.909401   0.848756  ...   0.787302   0.796226
# cashFlowCoverageRatios                 0.71751   0.657261  ...       None       None
# shortTermCoverageRatios                 5.8591    5.03965  ...       None       None
# capitalExpenditureCoverageRatio       -11.0376   -6.61182  ...   -4.70149   -4.90741
# dividendPaidAndCapexCoverageRatio      11.9129    19.1476  ...       None       None
# dividendPayoutRatio                   0.245267    0.25552  ...       None       None
# priceBookValueRatio                    30.5539    12.7097  ...     3.0585    2.02558
# priceToBookRatio                       30.5539    12.7097  ...     3.0585    2.02558
# priceToSalesRatio                      7.27232    4.42039  ...    1.11598    0.58085
# priceEarningsRatio                     34.7732    20.8135  ...    13.7831    18.2634
# priceToFreeCashFlowsRatio              27.2114    19.5272  ...    8.55887    5.27995
# priceToOperatingCashFlowsRatio          24.746    16.5738  ...    6.73842    4.20404
# priceCashFlowRatio                      24.746    16.5738  ...    6.73842    4.20404
# priceEarningsToGrowthRatio             10.9199    6.95768  ...    3.59395    4.58238
# priceSalesRatio                        7.27232    4.42039  ...    1.11598    0.58085
# dividendYield                       0.00705333  0.0122766  ...       None       None
# enterpriseValueMultiple                25.5589    14.7423  ...    4.28421    4.79672
# priceFairValue                         30.5539    12.7097  ...     3.0585    2.02558
#
# [55 rows x 36 columns]
